# %% [markdown]
# # seaborn data visualization Tutorial

# %% [markdown]
# ## barplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x105c7d9e0>, ci=95, n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75,  ax=None)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tip=sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='day', y='total_bill', data=tip)

# %%
sns.barplot(x='sex',y='total_bill',data=tip)

# %%
sns.barplot(x='day', y='total_bill', hue='sex',order=["Fri",'Sun','Sat','Thur'], data=tip)

# %%
sns.barplot(x='day', y='total_bill', hue='sex', palette='RdBu', data=tip)

# %%
sns.barplot(x='day', y='total_bill', hue='sex', palette='husl', data=tip)

# %%
sns.barplot(x='total_bill', y='day', hue='sex', palette='husl', data=tip)

# %%
sns.barplot(x='day', y='total_bill', hue='smoker', palette='autumn', data=tip)

# %%
sns.barplot(x='size', y='total_bill', hue='sex', palette='husl', data=tip)

# %%
sns.barplot(x='day', y='total_bill', hue='sex', palette='spring', estimator=np.median, data=tip)

# %%
sns.barplot(x='day', y='total_bill', hue='sex', palette='spring', estimator=np.median, data=tip)

# %% [markdown]
# ## distplot(a,hist=True/False, bins=None,kde=True/False,color=None,vertical=None, label=None,Norm_hist=None,ax=None)
# -consist histogram as well as kernal density or kde

# %%
num=np.random.randn(150)
sns.distplot(num)

# %%
x=pd.Series(num,name='variable x')
sns.distplot(x)

# %%
sns.distplot(num, vertical=True)

# %%
sns.distplot(num,hist=False)

# %%
sns.distplot(num,color='red')

# %%
sns.distplot(num,color='blue',bins=30)

# %% [markdown]
# ## boxplot(x=None,y=None,data=None, orient=None, hue=None, order=None, palette=None,color=None,saturation=0.75,ax=None,linewidth=None,width=0.8)

# %%
sns.boxplot(x="day", y="total_bill",data=tip)

# %%
sns.boxplot(x="day", y="total_bill",data=tip,hue='sex')

# %%
sns.boxplot(x="day", y="total_bill",data=tip,hue='sex',color='red',saturation=1.5,width=0.8,linewidth=5)

# %%
sns.boxplot(x="total_bill", y="day",data=tip,hue='sex',palette='winter_r')

# %% [markdown]
# ## stripplot(x=None,y=None,data=None,hue=None,hue_order=None,jitter=None,
# ## ax=None,palette=None,color=none,linewidth=0,split=True/False)

# %%
sns.stripplot(x='day',y='total_bill',data=tip)

# %%
sns.stripplot(x='day',y='total_bill', hue='sex',data=tip)

# %%
sns.stripplot(x='day',y='total_bill', hue='sex',hue_order=['Female','Male'],data=tip)

# %%
sns.stripplot(x='day',y='total_bill', hue='sex',jitter=True,data=tip)

# %%
sns.stripplot(x='day',y='total_bill', hue='sex',jitter=0.2,data=tip)

# %%
sns.stripplot(x='day',y='total_bill', hue='smoker', data=tip, split=True)
# Out:
# C:\Users\ankur\Anaconda3\lib\site-packages\seaborn\categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## PairGrid(data, hue=None, hue_order=None,pallete=None,vars=None,
# ## x_vars=None,y_vars=None,aspect=1,height=2.5,size=None)

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
x=sns.PairGrid(iris)
y=x.map(plt.scatter)
y

# %%
x=sns.PairGrid(iris)
y=x.map_diag(plt.hist)
y=x.map_offdiag(plt.scatter)
y

# %%
x=sns.PairGrid(iris,hue='species')
y=x.map(plt.scatter)
y.add_legend()
y

# %%
x=sns.PairGrid(iris,hue='species',vars=['sepal_length','sepal_width'])
y=x.map(plt.scatter)
y.add_legend()
y

# %%
x=sns.PairGrid(iris,hue='species')
y=x.map(sns.regplot)
y.add_legend()
y

# %%
x=sns.PairGrid(iris,hue='species',hue_kws={'marker':['d','s','+']})
y=x.map(plt.scatter)
y.add_legend()
y

# %% [markdown]
# ## FacetGrid(data,row=None,col=None,hue=None,hue_order=None,row_order=None,
# ##  col_order=None,xlim=None,ylim=None,hue_kws=None,aspect=1,height=3,size=None)

# %%
x=sns.FacetGrid(tip,row='smoker', col='time')
y=x.map(plt.hist, 'total_bill')
y

# %%
x=sns.FacetGrid(tip,row='smoker', col='time')
y=x.map(plt.scatter, 'total_bill','tip')
y

# %%
x=sns.FacetGrid(tip,hue='smoker', col='time')
y=x.map(plt.scatter, 'total_bill','tip')
y.add_legend()

# %%
x=sns.FacetGrid(tip,row='smoker', col='time')
y=x.map(sns.regplot, 'total_bill','tip')
y

# %% [markdown]
# ## Heatmap()

# %%
normal=np.random.rand(12,15)
sns.heatmap(normal)

# %%
sns.heatmap(normal,annot=True)

# %%
sns.heatmap(normal,vmin=0,vmax=2)

# %%
sns.heatmap(normal,vmin=0,vmax=3)

# %%
sns.heatmap(normal,vmin=0,vmax=0.5)

# %%
flights=pd.read_csv('flights.csv')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights=flights.pivot('year','month','passengers')
sns.heatmap(flights)

# %%
sns.heatmap(flights,annot=True)

# %%
sns.heatmap(flights,annot=True,fmt='d')

# %%
sns.heatmap(flights,linewidths=0.9,annot=True,fmt='d')

# %%
sns.heatmap(flights,cmap='RdBu',annot=True,fmt='d')

# %%
sns.heatmap(flights,cmap='summer',annot=True,fmt='d')

# %%
sns.heatmap(flights,cmap='winter_r',annot=True,fmt='d')

# %%
sns.heatmap(flights,cmap='coolwarm',annot=True,fmt='d')

# %%
sns.heatmap(flights,center=flights.loc[1954,'June'],annot=True,fmt='d')

# %% [markdown]
# ## kdeplot()

# %%
mean=[0,0]
cov=[[0.2,0],[0,3]]
x_axis,yaxis=np.random.multivariate_normal(mean,cov,size=40).T
sns.kdeplot(x_axis)

# %%
mean=[0,0]
cov=[[0.2,0],[0,3]]
x_axis,y_axis=np.random.multivariate_normal(mean,cov,size=40).T
sns.kdeplot(y_axis)

# %%
mean=[0,0]
cov=[[0.2,0],[0,3]]
x_axis,yaxis=np.random.multivariate_normal(mean,cov,size=40).T
sns.kdeplot(x_axis,shade=True, color='green')

# %%
sns.kdeplot(x_axis,y_axis)

# %%
sns.kdeplot(x_axis,y_axis,shade=True)

# %%
sns.kdeplot(x_axis,y_axis,cmap='RdBu')

# %%
sns.kdeplot(x_axis,y_axis,n_levels=35,cmap='coolwarm')

# %%
sns.kdeplot(y_axis,bw=1.5)

# %%
sns.kdeplot(y_axis)

# %%
iris=sns.load_dataset('iris')

# %%
setosa=iris.loc[iris.species=='setosa']
versicolor=iris.loc[iris.species=='versicolor']

# %%
sns.kdeplot(setosa.petal_length,setosa.petal_width)
sns.kdeplot(versicolor.petal_length,versicolor.petal_width)

# %%
sns.kdeplot(setosa.petal_length,setosa.petal_width,cmap='coolwarm')
sns.kdeplot(versicolor.petal_length,versicolor.petal_width,cmap='RdBu')
